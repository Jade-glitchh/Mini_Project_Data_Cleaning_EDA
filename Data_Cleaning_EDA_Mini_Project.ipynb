# %% [markdown]
# # Superstore Sales Dataset - retail sales & profit analysis

# %% [markdown]
# #Import data analysis tools

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Load Superstore Sales Dataset

# %%
import pandas as pd
df = pd.read_csv("Superstore.csv", encoding='latin1')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   9/11/2013  12/11/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   9/11/2013  12/11/2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11/10/2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11/10/2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# #Data cleaning - handling missing values

# %%
df.dropna()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156   9/11/2013  12/11/2013    Second Class
# 1          2  CA-2013-152156   9/11/2013  12/11/2013    Second Class
# 2          3  CA-2013-138688  13-06-2013  17-06-2013    Second Class
# 3          4  US-2012-108966  11/10/2012  18-10-2012  Standard Class
# 4          5  US-2012-108966  11/10/2012  18-10-2012  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2011-110422  22-01-2011  24-01-2011    Second Class
# 9990    9991  CA-2014-121258  27-02-2014    4/3/2014  Standard Class
# 9991    9992  CA-2014-121258  27-02-2014    4/3/2014  Standard Class
# 9992    9993  CA-2014-121258  27-02-2014    4/3/2014  Standard Class
# 9993    9994  CA-2014-119914    5/5/2014   10/5/2014    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# #Data cleaning - standardizing categorical/text columns

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df
# Out:
#       row_id        order_id  order_date   ship_date       ship_mode  \
# 0          1  CA-2013-152156   9/11/2013  12/11/2013    Second Class
# 1          2  CA-2013-152156   9/11/2013  12/11/2013    Second Class
# 2          3  CA-2013-138688  13-06-2013  17-06-2013    Second Class
# 3          4  US-2012-108966  11/10/2012  18-10-2012  Standard Class
# 4          5  US-2012-108966  11/10/2012  18-10-2012  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2011-110422  22-01-2011  24-01-2011    Second Class
# 9990    9991  CA-2014-121258  27-02-2014    4/3/2014  Standard Class
# 9991    9992  CA-2014-121258  27-02-2014    4/3/2014  Standard Class
# 9992    9993  CA-2014-121258  27-02-2014    4/3/2014  Standard Class
# 9993    9994  CA-2014-119914    5/5/2014   10/5/2014    Second Class
#
#      customer_id     customer_name    segment        country             city  \
# ...

# %% [markdown]
# #Data cleaning - converting data types

# %%
df['order_date'] = df['order_date'].astype(str).str.replace(r'[-.\s]', '/', regex=True)
df['ship_date'] = df['ship_date'].astype(str).str.replace(r'[-.\s]', '/', regex=True)

df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce', dayfirst=True)
df['ship_date'] = pd.to_datetime(df['ship_date'], errors='coerce', dayfirst=True)

# %% [markdown]
#  #Transform - create new columns

# %%
df['profit_margin'] = df['profit']/df['sales']
df.head()
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ... region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         product_id         category sub-category  \
# ...

# %% [markdown]
# #Transform - fix inconsistent  categories or mislabeled values

# %%
columns = ['category', 'sub-category', 'region', 'customer_name']
df[columns] = df[columns].apply(lambda col: col.astype(str).str.strip().str.lower().str.title())
df
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 9990    9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9991    9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9992    9993  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9993    9994  CA-2014-119914 2014-05-05 2014-05-10    Second Class
#
#      customer_id     customer_name    segment        country             city  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# #Extract time-based features

# %%
df['order_date'].dt.year
# Out:
# 0       2013
# 1       2013
# 2       2013
# 3       2012
# 4       2012
#         ...
# 9989    2011
# 9990    2014
# 9991    2014
# 9992    2014
# 9993    2014
# Name: order_date, Length: 9994, dtype: int32

# %%
df['order_date'].dt.strftime('%B')
# Out:
# 0       November
# 1       November
# 2           June
# 3        October
# 4        October
#           ...
# 9989     January
# 9990    February
# 9991    February
# 9992    February
# 9993         May
# Name: order_date, Length: 9994, dtype: object

# %%
df['order_date'].dt.strftime('%A, %d')
# Out:
# 0       Saturday, 09
# 1       Saturday, 09
# 2       Thursday, 13
# 3       Thursday, 11
# 4       Thursday, 11
#             ...
# 9989    Saturday, 22
# 9990    Thursday, 27
# 9991    Thursday, 27
# 9992    Thursday, 27
# 9993      Monday, 05
# Name: order_date, Length: 9994, dtype: object

# %% [markdown]
# #Data exploration

# %%
df.describe()
# Out:
#             row_id                     order_date  \
# count  9994.000000                           9994
# mean   4997.500000  2013-04-30 19:20:02.401441024
# min       1.000000            2011-01-04 00:00:00
# 25%    2499.250000            2012-05-23 00:00:00
# 50%    4997.500000            2013-06-27 00:00:00
# 75%    7495.750000            2014-05-15 00:00:00
# max    9994.000000            2014-12-31 00:00:00
# std    2885.163629                            NaN
#
#                            ship_date   postal_code         sales     quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2013-05-04 18:20:49.229537792  55190.379428    229.858001     3.789574
# min              2011-01-08 00:00:00   1040.000000      0.444000     1.000000
# 25%              2012-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2013-06-30 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
df_corr= df.corr(numeric_only=True)
df_corr
# Out:
#                  row_id  postal_code     sales  quantity  discount    profit  \
# row_id         1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# postal_code    0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# sales         -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# quantity      -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# discount       0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# profit         0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000
# profit_margin -0.020355    -0.064404  0.003444 -0.005280 -0.864452  0.223732
#
#                profit_margin
# row_id             -0.020355
# postal_code        -0.064404
# sales               0.003444
# quantity           -0.005280
# discount           -0.864452
# profit              0.223732
# profit_margin       1.000000

# %% [markdown]
# #Data Visualization

# %%
df['category'].value_counts()
# Out:
# category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
ax= df['category'].value_counts().plot(kind='bar', title='Category Distributions')
ax.set_xlabel('category')
ax.set_ylabel('Count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.plot(kind='scatter', x= 'sales', y= 'profit', title= 'Sales Vs. Profit')
plt.show()

# %%
#using seaborn to group by
sns.scatterplot(x='sales', y='profit',hue='category', data=df)
# Out:
# <Axes: xlabel='sales', ylabel='profit'>

# %%
df['delivery_days'] = (df['ship_date'] - df['order_date']).dt.days

# Basic histogram of delivery times
sns.histplot(df['delivery_days'], bins=20, kde=True)
plt.title('Delivery Time Distribution')
plt.xlabel('Days to Ship')
plt.ylabel('Number of Orders')
plt.show()

# %%
top_customers = df.groupby('customer_name').agg({'sales':'sum', 'profit':'sum'}).nlargest(10, 'sales')
top_customers.plot(kind='bar', figsize=(12, 6))
plt.title('Top 10 customer: Sale and Profit')
plt.show()

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
df.to_csv('Data_cleaning_EDA.csv', index=False)

# %% [markdown]
# #Insight

# %% [markdown]
# - The business is heavily dependent on low-margin, high-volume categories. Strategic promotions could shift focus toward Technology, which provides greater returns per unit sold.
# - Discounts or shipping costs may be eroding profit margins for specific segments
# - Delivery operations appear consistent. Optimization could target rare outliers for logistics cost savings.
# - A few high-value customers contribute significantly to profits and sales — these could be retained with loyalty programs.
